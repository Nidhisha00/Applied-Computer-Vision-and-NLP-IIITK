# %% [markdown]
# <a href="https://colab.research.google.com/github/Nidhisha00/Applied-Computer-Vision-and-NLP-IIITK/blob/main/Day2/Image_reading_and_showing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import cv2  # OpenCV library for image processing
import numpy as np  # Numerical computing library
from google.colab.patches import cv2_imshow  # Function to display images in Google Colab

# %%
# Create a NumPy array and check its type
print(type(np.array([1,2,3])))
# Out:
# <class 'numpy.ndarray'>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-13e906a9-75a1-4f5e-add0-1b5dec9a3bd4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-13e906a9-75a1-4f5e-add0-1b5dec9a3bd4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv2.imread("puppy.jpg")

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=643x360>

# %%
# Shape returns the image size as (height, width, number of channels)
print(img.shape)
# Out:
# (360, 643, 3)

# %%
# Display the data type of pixel values
print(img.dtype)
# Out:
# uint8

# %%
# Display the total number of elements in the image array
print(img.size)
# Out:
# 694440
